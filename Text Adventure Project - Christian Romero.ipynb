# %%
"""
    Docstring:

    A) Introduction:
    
    This text adventure game is based on the movie "Angels & Demons"
    by Dan Brown (2000). Be prepared, as your skills will be tested
    In order to save Vatican city from a terrifying threat. this game
    counts with __ stages:
    
    Intro: introducing main character and meeting an unexpected visitor.
    Stage 1: Decide whether you you will be part of the mission or not.
             (you might fly on a chopper or a plane! :o)
    Stage 2: A scientist will join you on your quest, not before testing
             your knowledge.
    Stage 3: Though desicion to make, what part of the city should you go?
    Stage 4: Two possible endings on the horizon. You might need to deactivate
             a bomb!
    
    B) Known Bugs and/or Errors:
    None.
"""


from datetime import datetime  #IMPORT DATETIME TO KNOW TODAY'S DATE AND TIME
from time import sleep         #IMPORT SLEEP TO PAUSE THE PRINTING FOR BETTER USER EXPERIENCE
import random                  #IMPORT RANDOM TO CHOOSE A RANDOM NUMBER
import sys                     #IMPORT SYS TO EXIT THE PROGRAM



#DEFINING THE START FUNCTION TO INITIALIZE AND INTRODUCE THE GAME
def start():  

    #CREATE A "FOR LOOP" TO ITERATE OVER THE WELCOME MESSAGE AND PRINT LETTER BY LETTER LIKE TYPEWRITER
    welcome = "\nHello player! Welcome to the text adventure game based on the movie...\n" 
    
    for letter in welcome:
        sleep(0.08)           #TIME IT WILL TAKE BETWEEN ONE LETTER AND THE NEXT
        sys.stdout.write(letter)
        sys.stdout.flush()
    
    sleep(0.5)                  #SLEEP FOR 0.5 SECONDS TO PRINT THE NAME OF THE GAME
    
                            
    print("""
    
     ▄▄▄·  ▐ ▄  ▄▄ • ▄▄▄ .▄▄▌  .▄▄ ·      ▄▄▄·  ▐ ▄ ·▄▄▄▄      ·▄▄▄▄  ▄▄▄ .• ▌ ▄ ·.        ▐ ▄ .▄▄ · 
    ▐█ ▀█ •█▌▐█▐█ ▀ ▪▀▄.▀·██•  ▐█ ▀.     ▐█ ▀█ •█▌▐███▪ ██     ██▪ ██ ▀▄.▀··██ ▐███▪▪     •█▌▐█▐█ ▀. 
    ▄█▀▀█ ▐█▐▐▌▄█ ▀█▄▐▀▀▪▄██▪  ▄▀▀▀█▄    ▄█▀▀█ ▐█▐▐▌▐█· ▐█▌    ▐█· ▐█▌▐▀▀▪▄▐█ ▌▐▌▐█· ▄█▀▄ ▐█▐▐▌▄▀▀▀█▄
    ▐█ ▪▐▌██▐█▌▐█▄▪▐█▐█▄▄▌▐█▌▐▌▐█▄▪▐█    ▐█ ▪▐▌██▐█▌██. ██     ██. ██ ▐█▄▄▌██ ██▌▐█▌▐█▌.▐▌██▐█▌▐█▄▪▐█
     ▀  ▀ ▀▀ █▪·▀▀▀▀  ▀▀▀ .▀▀▀  ▀▀▀▀      ▀  ▀ ▀▀ █▪▀▀▀▀▀•     ▀▀▀▀▀•  ▀▀▀ ▀▀  █▪▀▀▀ ▀█▄▀▪▀▀ █▪ ▀▀▀▀ 

    """)
    
    input("""       < Press any key to continue >""")  #INPUTS TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
     
                                                       
    print(f"""
It's {datetime.now().strftime('%h %d')} and the day could not be more beautiful in Boston.
Starting the day with a cup of coffee and reading the New York
Times, right before heading to the pool at Harvard University 
campus for an early swim to get the day going.\n""")   #DYNAMICALLY PRINT SHOWING TODAY'S DATE USING DATETIME.NOW()
    
    input("""       < Press any key to continue >""")  #INPUTS TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
    
                                                       
    print(f"""    
\033[1mPool Assistant:\033[0m Good morning...uhmmm...OH NO, I forgot your
name again...Would you be so kind to remind me please?

\033[1mYou:\033[0m No problem, it must be hard to remember everyone's name
in here, no? Anyway...My name is ...\n""") # \033[1m  AND \033[0m ARE USED TO CREATE BOLD EFFECT.
    
    global name                                 #CREATE GLOBAL VARIABLE NAME TO BE USED IN EVERY FUNCTION OF THE GAME
    
    name = input("Type your name: ")            #INPUT FOR YOUR NAME
    name = name.lower()                         #LOWERCASE THE STRINGS, IN CASE SOMEONE WRITES IN UPPERCASE
    name = name.capitalize()                    #CAPITALIZE THE FIRST LETTER OF THE NAME
    
                                                
    print(f"""
\033[1mPool Assistant:\033[0m Excuse my bad memory {name}. I just want to let
you know that you've got a visitor in the facilities. He says he's
coming from the Vatican and seems to be in a hurry. He's asking to 
see you inmmediately!\n""")                     #DYNAMICALLY PRINT USING PLAYER'S NAME
    
    sleep(1)                                    #DELAY PRINT TO IMPROVE USER EXPERIENCE
    
    print(f"""\033[1m{name}:\033[0m THE VATICAN?? Something really bad must have happened...\n""")
    
    print("""You rapidly get out of the pool and run into the lockers to dry. 
Receiving people in swimwear has never been your favourite thing
to do.\n""")
    
    input("""       <Press any key to continue>""")  #INPUTS TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
    
    print("""
\033[1mClaudio:\033[0m Good morning Professor, my name is Claudio Vincenzi, from
'Corpo della Gendarmeria Vaticano'. In other words: the Vatican Police.
We are under attack by a group who sent us this symbol...\n """)
    
    input("""       <Press any key to see symbol>""") #INPUTS TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
    
    sleep(1)                                          #DELAY PRINT TO IMPROVE USER EXPERIENCE
    
                                                      #PRINT ASCII ART
    print(""" 
    
         ██▓ ██▓     ██▓     █    ██  ███▄ ▄███▓ ██▓ ███▄    █  ▄▄▄     ▄▄▄█████▓ ██▓
        ▓██▒▓██▒    ▓██▒     ██  ▓██▒▓██▒▀█▀ ██▒▓██▒ ██ ▀█   █ ▒████▄   ▓  ██▒ ▓▒▓██▒
        ▒██▒▒██░    ▒██░    ▓██  ▒██░▓██    ▓██░▒██▒▓██  ▀█ ██▒▒██  ▀█▄ ▒ ▓██░ ▒░▒██▒
        ░██░▒██░    ▒██░    ▓▓█  ░██░▒██    ▒██ ░██░▓██▒  ▐▌██▒░██▄▄▄▄██░ ▓██▓ ░ ░██░
        ░██░░██████▒░██████▒▒▒█████▓ ▒██▒   ░██▒░██░▒██░   ▓██░ ▓█   ▓██▒ ▒██▒ ░ ░██░
        ░▓  ░ ▒░▓  ░░ ▒░▓  ░░▒▓▒ ▒ ▒ ░ ▒░   ░  ░░▓  ░ ▒░   ▒ ▒  ▒▒   ▓▒█░ ▒ ░░   ░▓  
         ▒ ░░ ░ ▒  ░░ ░ ▒  ░░░▒░ ░ ░ ░  ░      ░ ▒ ░░ ░░   ░ ▒░  ▒   ▒▒ ░   ░     ▒ ░
         ▒ ░  ░ ░     ░ ░    ░░░ ░ ░ ░      ░    ▒ ░   ░   ░ ░   ░   ▒    ░       ▒ ░
         ░      ░  ░    ░  ░   ░            ░    ░           ░       ░  ░         ░                                                                            
    """)
    
    input("""       <Press any key to see hand back the symbol>""") #INPUT TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
    
    stage_1()                               #MOVE INTO STAGE_1 AFTER THE GAME INTRO

  


    
#DEFINING THE FIRST STAGE FUNCTION. HERE PLAYER WILL INPUT A NUMBER BETWEEN 1-10, WHERE [1-4] SHOW UNAVAILABILITY
#AND [5-10] SHOW AVAILABILITY. IF PLAYER SHOWS UNAVAILABILITY, HE WILL BE OFFERED THE OPTION TO RECONSIDER IT.
def stage_1():
    
    print(f"""
\033[1mClaudio:\033[0m So {name}... from 1-10 (1 being the least - 10 being the most)
what is your availability right now?\n""")                      #ASK QUESTION TO THE USER

    number = input("Type a number between 1 and 10:  ")         #REQUESTING USER INPUT
    
    if number=='1' or number=='2' or number=='3' or number=='4': #CHECKING FOR UNAVAILABILITY WITH CONDITIONAL "IF"
       
        print("""
\033[1mClaudio:\033[0m I'm very saddened to hear this, we were counting with you! I 
guess I should leave soon, the Vatican Police is waiting for me...We will
look for another symbologist with more time.
        """)
        
        desicion_1()  #FUNCTION TO RECONSIDER UNAVAILABILITY. THIS FUNCTION HAS A "POSITIVE() FUNCTION" AND "FAIL() FUNCTION" IN IT.
        
    elif number=='5' or number=='6' or number=='7' or number=='8' or number=='9' or number=='10': #CHECKING FOR AVAILABILITY
        positive()    #FUNCTION THAT LEADS TO THE NEXT STAGE                                           
        
    else:             #WHEN INPUT IS NOT BETWEEN [1-10] IT WILL START THE QUESTION AGAIN
        print("\nInvalid entry. Please try again.\n")
        stage_1()     

        
        
        

#DEFINING POSITIVE WHICH IS AN INTERMEDIATE FUNCTION WHICH WILL RECONSIDER YOUR AVAILABILITY AND WILL
#MAKE A RANDOM CHOICE FOR YOU TRAVEL TO ROME EITHER BY HELICOPTER OR AIRPLANE.
def positive():
    print(f"""
\033[1mClaudio:\033[0m Perfect!! This is what I wanted to hear! Now...let's get 
going {name}, we have a long journey ahead of us.\n""")
    
    sleep(1)                          #SLEEP TO DELAY THE PRINTING AND IMPROVE USER EXPERIENCE
    
    travel = random.randint(1, 2)     #DEFINE VARIABLE "TRAVEL" AND ASSIGN A RANDOM INTEGER EITHER 1 OR 2 USING RANDOM
    
    if travel == 1:                   #CHECK FOR CONDITION 1. 1 = TRAVEL BY HELICOPTER
        print(f"""{'*'*68} 
    
{name} and Claudio board the helicopter and start their travel 
towards Vatican city, there's no time to waste!
    
{'*'*68}""")            #USE DYNAMIC PRINTING AND STRING OPERATIONS
    
        chopper()       #SINCE CONDITION 1 WAS MET. CHOPPER() PRINTS AN ASCII HELICOPTER
        
        input('<Press any key to continue>\n') #INPUT TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
        
        stage_2()       #MOVE TO STAGE 2
        
    if travel == 2:                    #CHECK FOR CONDITION 2. 2 = TRAVEL BY AIRPLANE
    
        print(f"""{'*'*68} 
    
{name} and Claudio board the airplane and start their travel 
towards Vatican city, there's no time to waste!
    
{'*'*68}""")            #USE DYNAMIC PRINTING AND STRING OPERATIONS
    
        plane()         #SINCE CONDITION 2 WAS MET. PLANE() PRINTS AN ASCII AIRPLANE
    
        input('<Press any key to continue>\n') #INPUT TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
        
        stage_2()       #MOVE TO STAGE 2




#DEFINE A SIMPLE FUNCTION TO PRINT A HELICOPTER        
def chopper():
    print("""
                ,,,,,,,,,,---''''---,,,,,,,,,,
      --''''''''          ````][''''          ''''''''--
                           _3'''':.
 _                  .,---------------.
 \\    / _________./  |[__]| o   |J@"\\__
  \\==o=========:;    |____|[IL__|''''/_/')
     /            `'-,._____===\=_____.,-'
                          \         \     
                    '''''''''''''''''''''''
    """)



#DEFINE A SIMPLE FUNCTION TO PRINT AN AIRPLANE
def plane():
    print("""
             __  _
            \ `/ |
             \__`!
             / ,' `-.__________________
            '-'\_____                LI`-.
               <____()-=O=O=O=O=O=[]====--)
                 `.___ ,-----,_______...-'
                      /    .'
                     /   .'
                    /  .'         
                    `-'
    """)    
    
   
    
#DEFINING THE SECOND STAGE FUNCTION. HERE PLAYER WILL MEET A NEW CHARACTER AND SHE WILL ASK THREE QUESTIONS FROM
#A QUESTION POOL. USER MUST ANSWER THREE QUESTIONS AND CAN ONLY GET ONE QUESTION WRONG. TWO WRONG ANSWERS WILL
#CALL FOR A FAIL. AN INCORRECT INPUT WILL RESTART THE QUESTIONS. 
def stage_2():
    
    print(f"""
It's {datetime.now().strftime('%H:%M')}. At the entrance of the Swiss Guard headquearters, Vittoria
Vetra is waiting for you. She's a scientist from the C.E.R.N as is
extremely worried that antimatter stolen from the lab, will be used
by the 'Illuminati'to destroy the city.
""")                                        #DYNAMICALLY PRINT. USING DATETIME() TO SHOWCASE ACTUAL TIME.
    
    input('<Press any key to continue>\n')  ##INPUT TO SLOW THE GAME AND IMPROVE USER EXPERIENCE
    
    print(f"""
\033[1mVittoria:\033[0m {name}, in order for me to know if I will join your party,
I need to ask you three questions! I Hope you know a little bit about
science...

[REMINDER: if your entry is invalid, the questions will re-start.
two wrong answers and the game is over]""")  #DYNAMICALLY PRINT. USING GLOBAL VARIABLE NAME.

    random_questions()                       #FUNCTION TO CALL FOR THE 3 QUESTIONS
    

    
#FUNCTION DESIGNED TO CHOOSE THREE QUESTIONS OUT OF A POOL OF 5 POSSIBLE OPTIONS.    
def random_questions():
    
    #CREATING A LIST OF QUESTIONS AND ASSIGNING IT TO VARIABLE "QUESTION_POOL"
    question_pool = ["Do you know where the C.E.R.N is located?",
                     "What is considered the opposite state of matter?",
                     "What is another name for the Higgs boson?",
                     "How was the universe created?",
                     "How long is the tunnel of the large hadron collider?"]
    
    number_questions = 3  #DEFINING VARIABLE FOR THE NUMBER OF QUESTIONS WE WANT TO ASK
    chances = 2           #DEFINING VARIABLE FOR THE NUMBER OF CHANCES TO ANSWER
    
    used_questions = []   #CREATING AN EMPTY LIST THAT WILL BE USED TO STORE THE USED QUESTIONS
    
    while number_questions > 0:     #OUTERMOST LOOP THAT WILL CHECK THAT THERE ARE STILL QUESTIONS TO BE ASKED
        
        chosen_question = random.choice(question_pool) #USE RANDOM.CHOICE() TO SELECT A QUESTION FROM THE POOL. ASSIGN IT TO VARIABLE.
        
        if chosen_question not in used_questions:      #CHECK FOR CONDITION THAT THE QUESTION HASN'T BEEN USED.
    
            if chosen_question == question_pool[0]:    #CHECK IF THIS IS QUESTION 1.
                input('<Press any key to continue>\n') #INPUT TO IMPROVE USER EXPERIENCE
                print(chosen_question)                 #PRINT QUESTION 1 
                print("""\n1. Switzerland
2. France
3. Italy\n""")  #PRINT QUESTION 1 MULTIPLE CHOICE.
                first_answer = input("\n")             #ASK FOR USER'S ANSWER AND ASSIGN IT TO VARIABLE
                first_answer = first_answer.lower()    #TURN ANSWER TO LOWERCASE
                
                if "switzerland" in first_answer or "1" in first_answer or "land" in first_answer or "switz" in first_answer: #CONDITIONALS TO CHECK FOR QUESTION 1'S CORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE.
                    number_questions = number_questions -1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    print(f"""\nThis is correct {name}! You still got {number_questions} questions left!""") #DYNAMIC PRINTING TO SHOW USER HOW MANY QUESTIONS ARE LEFT
                    used_questions.append(chosen_question)  #USE APPEND() TO ADD USED QUESTION TO THE USED_QUESTIONS LIST.

                elif "france" in first_answer or "2" in first_answer or "italy" in first_answer or "3" in first_answer: #CONDITIONALS TO CHECK FOR QUESTION 1'S INCORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE.
                    number_questions = number_questions - 1 #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    chances -=1          #DECREASE NUMBER OF CHANCES BY 1 SINCE ANSWER WAS INCORRECT.
                    
                    if chances != 0:     #CONDITIONAL TO CHECK THAT YOU STILL COUNT WITH A CHANCE TO PLAY. 
                        print("\nOH NO! I think you need to research a bit more about the Organisation européenne pour la recherche nucléaire!")
                        print(f"""\n{name}, you got {chances} chances left and {number_questions} questions to go!!""")
                        used_questions.append(chosen_question) #GET A WRONG ANSWER MESSAGE, BUT APPENDS QUESTION TO USED_QUESTIONS LIST.
                        
                    else:               #IN CASE YOUR CHANCES ARE 0. YOU FAIL THE GAME.
                        fail()
                        
                else:                   #IN CASE YOU INPUT INCORRECTLY FOR THE QUESTION IT WILL RESTART THE QUESTIONS STAGE AGAIN.
                    print("\nInvalid entry. Questions will re-start.\n")
                    random_questions()
    
            elif chosen_question == question_pool[1]:   #CHECK IF THIS IS QUESTION 2.
                input('<Press any key to continue>\n')  #INPUT TO IMPROVE USER EXPERIENCE
                print(chosen_question)                  #PRINT QUESTION 2 
                print("""\n1. Air
2. Antimatter
3. Gravity\n""")   #PRINT QUESTION 2 MULTIPLE CHOICE.
                second_answer = input("\n")             #ASK FOR USER'S ANSWER AND ASSIGN IT TO VARIABLE
                second_answer = second_answer.lower()   #TURN ANSWER TO LOWERCASE
                
                if "antimatter" in second_answer or "anti" in second_answer or "2" in second_answer: #CONDITIONALS TO CHECK FOR QUESTION 2'S CORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE
                    number_questions = number_questions -1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    print(f"""\nThat is correct {name}! you got {number_questions} questions left!""") #DYNAMIC PRINTING TO SHOW USER HOW MANY QUESTIONS ARE LEFT
                    used_questions.append(chosen_question) #USE APPEND() TO ADD USED QUESTION TO THE USED_QUESTIONS LIST.

                elif "air" in second_answer or "1" in second_answer or "gravity" in second_answer or "3" in second_answer: #CONDITIONALS TO CHECK FOR QUESTION 2'S INCORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE.
                    number_questions = number_questions - 1 #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    chances -= 1                            #DECREASE NUMBER OF CHANCES BY 1 SINCE ANSWER WAS INCORRECT.
                    
                    if chances != 0:                      #CONDITIONAL TO CHECK THAT YOU STILL COUNT WITH A CHANCE TO PLAY.
                        print("\nOH NO! you need to learn a bit more about physics!")
                        print(f"""\n{name}, you got {chances} chances left and {number_questions} questions to go!!""")
                        used_questions.append(chosen_question) #GET A WRONG ANSWER MESSAGE, BUT APPENDS QUESTION TO USED_QUESTIONS LIST.
                        
                    else:               #IN CASE YOUR CHANCES ARE 0. YOU FAIL THE GAME.
                        fail()
                else:                   #IN CASE YOU INPUT INCORRECTLY FOR THE QUESTION IT WILL RESTART THE QUESTIONS STAGE AGAIN.
                    print("\nInvalid entry. Questions will re-start.\n")
                    random_questions()


            elif chosen_question == question_pool[2]:     #CHECK IF THIS IS QUESTION 3
                input('<Press any key to continue>\n')    #INPUT TO IMPROVE USER EXPERIENCE
                print(chosen_question)                    #PRINT QUESTION 3 
                print("""\n1. Hell atom
2. Photon
3. God particle\n""") #PRINT QUESTION 3 MULTIPLE CHOICE.
                third_answer = input("\n")                #ASK FOR USER'S ANSWER AND ASSIGN IT TO VARIABLE
                third_answer = third_answer.lower()       #TURN ANSWER TO LOWERCASE
                
                if "god" in third_answer or "3" in third_answer or "god particle" in third_answer or "particle" in third_answer or "godparticle" in third_answer: #CONDITIONALS TO CHECK FOR QUESTION 3'S CORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE
                    number_questions = number_questions -1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    print(f"""\nThat is correct {name}! you got {number_questions} questions left!""") #DYNAMIC PRINTING TO SHOW USER HOW MANY QUESTIONS ARE LEFT
                    used_questions.append(chosen_question)  #USE APPEND() TO ADD USED QUESTION TO THE USED_QUESTIONS LIST.

                elif "photon" in third_answer or "2" in third_answer or "hell" in third_answer or "atom" in third_answer or "hell atom" in third_answer or "hellatom" in third_answer or "1" in third_answer: #CONDITIONALS TO CHECK FOR QUESTION 3'S INCORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE
                    number_questions = number_questions - 1 #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    chances -= 1                            #DECREASE NUMBER OF CHANCES BY 1 SINCE ANSWER WAS INCORRECT.
                    
                    if chances != 0:                        #CONDITIONAL TO CHECK THAT YOU STILL COUNT WITH A CHANCE TO PLAY.         
                        print("\nOH NO! you need to learn a bit more about physics!")
                        print(f"""\n{name}, you got {chances} chances left and {number_questions} questions to go!""")
                        used_questions.append(chosen_question) #GET A WRONG ANSWER MESSAGE, BUT APPENDS QUESTION TO USED_QUESTIONS LIST.
                    
                    else:     #IN CASE YOUR CHANCES ARE 0. YOU FAIL THE GAME.
                        fail()
                else:       #IN CASE YOU INPUT INCORRECTLY FOR THE QUESTION IT WILL RESTART THE QUESTIONS 
                    print("\nInvalid entry. Questions will re-start.\n")
                    random_questions()


            elif chosen_question == question_pool[3]:      #CHECK IF THIS IS QUESTION 4
                input('<Press any key to continue>\n')     #INPUT TO IMPROVE USER EXPERIENCE
                print(chosen_question)                     #PRINT QUESTION 4
                print("""\n1. God                  
2. Big Bang
3. Aliens\n""")     #PRINT QUESTION4  MULTIPLE CHOICE
                fourth_answer = input("\n")                 #ASK FOR USER'S ANSWER AND ASSIGN IT TO VARIABLE
                fourth_answer = fourth_answer.lower()       #TURN ANSWER TO LOWERCASE
                
                if "big" in fourth_answer or "bang" in fourth_answer or "big bang" in fourth_answer or "bigbang" in fourth_answer or "2" in fourth_answer: #CONDITIONALS TO CHECK FOR QUESTION 4'S CORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE 
                    number_questions = number_questions -1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    print(f"""\nThat is correct {name}! you got {number_questions} questions left!""") #DYNAMIC PRINTING TO SHOW USER HOW MANY QUESTIONS ARE LEFT
                    used_questions.append(chosen_question)   #USE APPEND() TO ADD USED QUESTION TO THE USED_QUESTIONS LIST.

                elif "god" in fourth_answer or "1" in fourth_answer or "3" in fourth_answer or "aliens" in fourth_answer: #CONDITIONALS TO CHECK FOR QUESTION 4'S INCORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE
                    number_questions = number_questions - 1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER QUESTIONS BY 1.
                    chances -= 1                             #DECREASE NUMBER IF CHANCES BY 1 SINCE ANSWER EAS INCORRECT
                    
                    if chances != 0:                        #CONDITIONAL TO CHECK THAT YOU STILL COUNT WITH A CHANCE TO PLAY.
                        print("\nOH NO! you need to learn a bit more about physics!")
                        print(f"""\n{name}, you got {chances} chances left and {number_questions} questions to go!!""")
                        used_questions.append(chosen_question) #GET A WRONG ANSWER MESSAGE, BUT APPENDS QUESTION TO USED_QUESTIONS LIST.
                    
                    else:      #IN CASE YOUR CHANCES ARE 0. YOU FAIL THE GAME.
                        fail()
                else:          #IN CASE YOU INPUT INCORRECTLY FOR THE QUESTION IT WILL RESTART THE QUESTIONS
                    print("\nInvalid entry. Questions will re-start.\n")
                    random_questions()


            elif chosen_question == question_pool[4]:       #CHECK IF THIS IS QUESTION 5
                input('<Press any key to continue>\n')      #INPUT TO IMPROVE USER EXPERIENCE
                print(chosen_question)                      #PRINT QUESTION 5
                print("""\nA. 60 miles
B. 10 miles
C. 16 miles\n

[REMEMBER: OPTIONS FOR THIS QUESTION ARE "A, B, C".]""")   #PRINT QUESTION 5 MULTIPLE CHOICE
                fifth_answer = input("\n")                  #ASK FOR USER'S ANSWER AND ASSIGN IT TO VARIABLE
                fifth_answer = fifth_answer.lower()         #TURN ANSWER TO LOWERCASE
                
                if "16" in fifth_answer or "sixteen" in fifth_answer or "c" in fifth_answer: #CONDITIONALS TO CHECK FOR QUESTION 5'S CORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE
                    number_questions = number_questions -1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER OF QUESTIONS BY 1.
                    print(f"""\nThat is correct {name}! you got {number_questions} questions left!""")   #DYNAMIC PRINTING TO SHOW USER HOW MANY QUESTIONS ARE LEFT
                    used_questions.append(chosen_question)  #USE APPEND() TO ADD USED QUESTION TO THE USED_QUESTIONS LIST.

                elif "10" in fifth_answer or "ten" in fifth_answer or "b" in fifth_answer or "60" in fifth_answer or "sixty" in fifth_answer or "a" in fifth_answer:  #CONDITIONALS TO CHECK FOR QUESTION 5'S INCORRECT ANSWERS. USING "IN" TO IMPROVE USER EXPERIENCE
                    number_questions = number_questions - 1  #QUESTION HAS BEEN ANSWERED. DECREASE NUMBER QUESTIONS BY 1.
                    chances -= 1                            #DECREASE NUMBER IF CHANCES BY 1 SINCE ANSWER EAS INCORRECT
                    
                    if chances != 0:                        #CONDITIONAL TO CHECK THAT YOU STILL COUNT WITH A CHANCE TO PLAY.
                        print("\nOH NO! you need to learn a bit more about C.E.R.N!")
                        print(f"""\n{name}, you got {chances} chances left and {number_questions} questions to go!!""")
                        used_questions.append(chosen_question)  #GET A WRONG ANSWER MESSAGE, BUT APPENDS QUESTION TO USED_QUESTIONS LIST.
                    
                    else:        #IN CASE YOUR CHANCES ARE 0. YOU FAIL THE GAME.
                        fail()
                else:            #IN CASE YOU INPUT INCORRECTLY FOR THE QUESTION IT WILL RESTART THE QUESTIONS
                    print("\nInvalid entry. Questions will re-start.\n")
                    random_questions()
        
        else:           #IF THE RANDOM QUESTION SELECTED IS IN THE USED_QUESTION LIST...
            continue    #THEN IT WILL JUMP TO THE NEXT ITERATION.          
       
    
    #STAGE SUCCESS PRINT AFTER 3 QUESTIONS HAVE BEEN ANSWERED WITHOUT A FAIL()
    print(f"""
\033[1mVittoria:\033[0m You answered all my questions! You can count with me to 
look for the antimatter bomb that is hidden somewhere in rome.


\033[1m{name}:\033[0m Great! two minds are better than one. Also, I've read a bit
about the research that is done at the C.E.R.N. You are so smart...\n""") 
    
    input('<Press any key to continue>\n')                 #INPUT TO IMPROVE USER EXPERIENCE
    
    stage_3()                                              #GO TO STAGE 3
    

    
    
# #DEFINING THE THIRD STAGE FUNCTION. HERE PLAYER WILL DECIDE BETWEEN TWO DESTINATIONS.  
def stage_3():
    print(f"""\033[1mVittoria:\033[0m {name}, Let's decide now where we are headed! According to
the cameras in the city there are two locations we can start looking\n""")
    
    input('<Press any key to continue>\n')    #INPUT TO IMPROVE USER EXPERIENCE

    #PRINT STATEMENTS USING SOME ASCII ART TO SHOW DESTINATIONS
    print(f"""If we go north, we'll find Santa Maria Della Vitoria cathedral....
                                   
                                              
                                        -|-
                                         |
                                        /A\
                                       //^\\
                                     ,// _ \\,
                                     |/`/_\`\|
                                      |  ,  |
                                      | /^\ |
                                      |//'\\|
                                    ,//` _ `\\,
                                  ,//` .'|'. `\\,
                                ,//`   |-|-|   `\\,
                              ,//`     [_|_]     `\\,
                              |/T                 T\|
                                |  _   __ __   _  |
                                | /_\ |  |  | /_\ |
                                | |_| | .|. | |_| |
                                |     |__|__|     |
                                '----[_______]----'
                                      =======
                                     ======
                                  ====== \n""")
    
    input("Press any key to continue: \n")    #INPUT TO IMPROVE USER EXPERIENCE
   
    print(f"""If we go south we'll find Castel Sant Angelo...
    
    
                                  |>>>
                                  |
                    |>>>      _  _|_  _         |>>>
                    |        |;| |;| |;|        |
                _  _|_  _    \\.    .  /    _  _|_  _
               |;|_|;|_|;|    \\:. ,  /    |;|_|;|_|;|
               \\..      /    ||;   . |    \\.    .  /
                \\.  ,  /     ||:  .  |     \\:  .  /
                 ||:   |_   _ ||_ . _ | _   _||:   |
                 ||:  .|||_|;|_|;|_|;|_|;|_|;||:.  |
                 ||:   ||.    .     .      . ||:  .|
                 ||: . || .     . .   .  ,   ||:   |       
                 ||:   ||:  ,  _______   .   ||: , |        
                 ||:   || .   /+++++++\    . ||:   |
                 ||:   ||.    |+++++++| .    ||: . |
              __ ||: . ||: ,  |+++++++|.  . _||_   |
     ____--`~    '--~~__|.    |+++++__|----~    ~`---,      
-~-                     ~---__|,--~'                  ~~--
    """)
    
    sleep(1)  #ADDING A SMALL DELAY TO SHOWCASE TWO OPTIONS
    
    print("""\n\n Where whould you like to go?
    
    1. North, to Santa Maria Della Vittoria
    
    2. South, to Castel Sant' Angelo
    
    3. Nowhere! I want to go home, this is too scary!!""")  #PRINTING THREE POSSIBLE OPTIONS
    
    direction = input("\n> \n")         #ASKING USER FOR INPUT
    direction  = direction.lower()      #TURNING INPUT INTO LOWERCASE
    
    if "1" in direction or "north" in direction or "santa" in direction or "maria" in direction or "vittoria" in direction:
        stage_santa()                   #GO TO LOCATION SANTA MARIA DELLA VITTORIA.
    
    elif "2" in direction or "south" in direction or "castel" in direction or "sant" in direction or "vittoria" in direction:
        stage_castel()                  #GO TO LOCATION CASTEL SANT ANGELO
   
    elif "3" in direction or "nowhere" in direction or "home" in direction or "scary" in direction:
        print(f"""
\033[1m{name}:\033[0m I'm sorry Vittoria, this is it for me! I don't wanna die today! Take care..""")
        fail()                          #LEAVE THE GAME AND FAIL
      
    else:
        print("\nInvalid entry. Please try again.\n")
        stage_3()                       #INVALID ENTRY AND WILL RESTART THE STAGE.
    

    
#FUNCTION DEFINED TO BE ONE OF THE POSSIBLE LOCATIONS THE USER CAN DECIDE TO GO. IN THIS STAGE, LUCK WILL BE
#INVOLVED, AS A RANDOM CHOICE WILL DEFINE IF THE VILLAIN IS HERE OR IF THEY SHOULD GO TO OTHER LOCATION.
def stage_santa():
    
    print(f"""
\033[1m{name}:\033[0m Santa Maria della Vittoria is a Catholic church dedicated
to the Virgin Mary located in Rome. The church is known for the masterpiece
of Gian Lorenzo Bernini in the Cornaro Chapel: the Ecstasy of Saint Teresa.""")
    
    scenario = random.randint(1, 2)   #A RANDOM CHOICE BETWEEN THE TWO SCENARIOS
    
    if scenario == 1:  #CHECKING FOR SCENARIO ONE. THE VILLAIN IS HERE AND HE'S EASY TO CAPTURE. YOU WIN.
        
        print("""
\033[1mVittoria:\033[0m The Illuminati mentioned the 'Altars of science' in their journals.
They were scientists persecuted by the Church because if their knowledge. 
It makes sense that they want to seek revenge by destroying the temples. 
This is the right location, the bomb is here!!\n""")
        
        input('<Press any key to continue>\n') #INPUT TO IMPROVE USER EXPERIENCE
        
        sleep(1)
        
        print("""
\033[1mVittoria:\033[0m Wait a second...isn't that guy over there the Illuminati leader?
Let's go an catch him right now...he's in a vulnerable position!\n""")
        
        input('<Press any key to continue>\n')
        
        print(f"""
After a 30 mins chase, you finally caught the Illuminati leader and managed to 
deactivate the bomb. Vatican city is now saved thanks to you, {name}!\n""")
        
        complete()                #YOU WIN THE GAME IN THIS RANDOM SCENARIO.
        
    if scenario == 2:   #CHECKING FOR SCENARIO TWO. THE BOMB IS NOT HERE, YOU SHOULD GO TO CASTEL SANT ANGELO.
        
        print(f"""
\033[1mVittoria:\033[0m I have a gut feeling that we were fooled by the Illuminati! This 
is not the right location...the sculpture we saw in the camera is not the Ecstasy
of Saint Theresa... We must leave right now to Castel Sant' Angelo!\n""")
        
        input('<Press any key to continue>\n')
        
        stage_castel()  #GO TO THE OTHER LOCATION, CASTEL SANT ANGELO.
        

#FUNCTION DEFINED TO BE ONE OF THE POSSIBLE LOCATIONS THE USER CAN DECIDE TO GO. IF USER DECIDE TO GO TO THIS
#LOCATION HE WILL FIND A BOMB THAT HE NEEDS TO DEACTIVATE.       
def stage_castel():
    
    print(f"""
\033[1m{name}:\033[0m Castel Sant' Angelo It was initially commissioned by the Roman Emperor
Hadrian as a mausoleum for himself and his family. The building was later used
by the popes as a fortress and castle, and is now a museum. The structure was
once the tallest building in Rome.""")
    
    input("Press any key to continue: \n")
    
    print("""
\033[1mVittoria:\033[0m I hear a ticking somewhere close to that sculpture over there, let's
go and examine it\n""")
    
    input("Press any key to continue: \n")
    
    print("""
\033[1mVittoria:\033[0m Here it is! THE BOMB!! It's asking for a code. \n""")
    
    print("""
WHAT DAY IS TODAY?: [numbers from 1-31]
BE CAREFUL YOU ONLY HAVE ONCE CHANCE! NO ERRORS ACCEPTED!!!\n""")
    
    for i in range(10, 4, -1):  #A FOR LOOP TO SIMULATE A COUNTDOWN AND CREATE A BETTER USER EXPERIENCE.
        print(i,". . .", end="\n")
        sleep(1.5)
    
    code = input("\n> ")        #ASK USER FOR THE CODE (TODAY'S DATE)
    
    if code == datetime.now().strftime('%d'):   #CONDITIONAL CHECKING IF ANSWER IS CORRECT.
        
        for letter in 'BOMB SUCCESSFULLY DEACTIVATED...BOMB SUCCESSFULLY DEACTIVATED': #PRINT MESSAGE OF SUCCESSFULL DEACTIVATION
            sleep(0.08)               
            sys.stdout.write(letter)
            sys.stdout.flush()
          
        
        print(f"""\n
\033[1mVittoria:\033[0m WOW {name.upper()}!! WE DID IT!!! The Illuminati never stood
a chance against us!\n""")
        
        complete()              #COMPLETE THE GAME
        
    else:                          #IF ANSWER IS NOT CORRECT.
        for i in range(5, 0, -1):  #A LOOP FOR THE REST OF THE BOMB COUNTDOWN!
            print(i,"...", end="\n")
            sleep(1.5)
        
        print("""\nKABOOOOOOOOOMMMMMMMMMMMM!!!! \U0001f4a5 \U0001f4a5 \U0001f4a5""") #ADD EXPLOSION EMOJI FOR BOMB EXPLOSION
        
        fail()  #YOU FAIL THE GAME


#FUNCTION TO BE CALLED WHEN GAME IS SUCCESSFULLY COMPLETED        
def complete():
    
    sleep(1)
    
    print("""
 ______     ______     __    __     ______   __         ______     ______   ______     _____       
/\  ___\   /\  __ \   /\ "-./  \   /\  == \ /\ \       /\  ___\   /\__  _\ /\  ___\   /\  __-.     
\ \ \____  \ \ \/\ \  \ \ \-./\ \  \ \  _-/ \ \ \____  \ \  __\   \/_/\ \/ \ \  __\   \ \ \/\ \    
 \ \_____\  \ \_____\  \ \_\ \ \_\  \ \_\    \ \_____\  \ \_____\    \ \_\  \ \_____\  \ \____-    
  \/_____/   \/_____/   \/_/  \/_/   \/_/     \/_____/   \/_____/     \/_/   \/_____/   \/____/
    """)
    
    exit()

    
    
#FUNCTION TO BE CALLED WHEN THE GAME IS FAILED. IT GIVES THE OPTION TO RESTART THE GAME.    
def fail():
    
    sleep(1)
    
    print(""" 
 __  __     ______     __  __        ______   ______     __     __         ______     _____    
/\ \_\ \   /\  __ \   /\ \/\ \      /\  ___\ /\  __ \   /\ \   /\ \       /\  ___\   /\  __-.  
\ \____ \  \ \ \/\ \  \ \ \_\ \     \ \  __\ \ \  __ \  \ \ \  \ \ \____  \ \  __\   \ \ \/\ \ 
 \/\_____\  \ \_____\  \ \_____\     \ \_\    \ \_\ \_\  \ \_\  \ \_____\  \ \_____\  \ \____- 
  \/_____/   \/_____/   \/_____/      \/_/     \/_/\/_/   \/_/   \/_____/   \/_____/   \/____/ 
                                                                                               
""")
    
    restart = input("\nWould you like to start again? [Y/N]: \n\n") #ASK USER TO RESTART GAME.
    restart = restart.lower()
    
    if restart == 'y' or restart =='yes':                           #IF ANSWER IS POSITIVE, RESTART THE GAME.
        start()
    
    elif restart =='n' or restart =='no':                           #IF ANSWER IS NEGATIVE, THANK YOU MESSAGE AND EXIT GAME.
        print("Thank you for playing 'Angels & Demons'!")
        exit(0)
    
    else:                                                           #IF ANSWER INVALID, ASK AGAIN.                      
        print("\nInvalid entry. Please try again.\n")
        fail()

        
        
#QUICK FUNCTION DEFINED TO ASK USER TO RECONSIDER AVAILABILITY TO GO TO THE VATICAN
#CREATED TO AVOID GOING THRU THE PREVIOUS TEXT IN THE STAGE. IF ANSWER POSITIVE, GO TO NEXT STAGE. IF NEGATIVE, FAIL.
#IF INVALID, ASK AGAIN.
def desicion_1():
    
    desicion = input("Do you want to change your opinion? [Y/N] ")
    desicion = desicion.lower()
    
    if desicion == 'y' or desicion =='yes':
        positive()
        
    elif desicion =='n' or desicion =='no':
        fail()
    else:
        print("\nInvalid entry. Please try again.\n")
        desicion_1()

# %%
start()
# Out:
# Hello player! Welcome to the text adventure game based on the movie...
#
#
#      ▄▄▄·  ▐ ▄  ▄▄ • ▄▄▄ .▄▄▌  .▄▄ ·      ▄▄▄·  ▐ ▄ ·▄▄▄▄      ·▄▄▄▄  ▄▄▄ .• ▌ ▄ ·.        ▐ ▄ .▄▄ ·
#     ▐█ ▀█ •█▌▐█▐█ ▀ ▪▀▄.▀·██•  ▐█ ▀.     ▐█ ▀█ •█▌▐███▪ ██     ██▪ ██ ▀▄.▀··██ ▐███▪▪     •█▌▐█▐█ ▀.
#     ▄█▀▀█ ▐█▐▐▌▄█ ▀█▄▐▀▀▪▄██▪  ▄▀▀▀█▄    ▄█▀▀█ ▐█▐▐▌▐█· ▐█▌    ▐█· ▐█▌▐▀▀▪▄▐█ ▌▐▌▐█· ▄█▀▄ ▐█▐▐▌▄▀▀▀█▄
#     ▐█ ▪▐▌██▐█▌▐█▄▪▐█▐█▄▄▌▐█▌▐▌▐█▄▪▐█    ▐█ ▪▐▌██▐█▌██. ██     ██. ██ ▐█▄▄▌██ ██▌▐█▌▐█▌.▐▌██▐█▌▐█▄▪▐█
#      ▀  ▀ ▀▀ █▪·▀▀▀▀  ▀▀▀ .▀▀▀  ▀▀▀▀      ▀  ▀ ▀▀ █▪▀▀▀▀▀•     ▀▀▀▀▀•  ▀▀▀ ▀▀  █▪▀▀▀ ▀█▄▀▪▀▀ █▪ ▀▀▀▀
#
#
#        < Press any key to continue >
#
# It's Oct 20 and the day could not be more beautiful in Boston.
# Starting the day with a cup of coffee and reading the New York
# Times, right before heading to the pool at Harvard University
# campus for an early swim to get the day going.
#
#        < Press any key to continue >
#
# Pool Assistant: Good morning...uhmmm...OH NO, I forgot your
# ...
